# %% [markdown]
# General code to read in the xlxs file you want from github

# %%
import pandas as pd
import urllib.request

# %%
# INSERT THE NAME OF THE FILE YOU WANT HERE THIS IS JUST AN EXAMPLE
file = 'aquatic_plants_lakes.xlsx'

url = f"https://github.com/haleyej/clean_water_corps_data/raw/main/{file}"
urllib.request.urlretrieve(url, file)
# Out:
# ('aquatic_plants_lakes.xlsx', <http.client.HTTPMessage at 0x7f8455b95df0>)

# %% [markdown]
# Our data is in excel files, so we use pd.read_excel. If for whatever reason you're trying to access data from the repo that's in a different format, just change this to the appropriate function (probably pd.read_csv).

# %%
df = pd.read_excel(file)
df.head()
# Out:
#   Lake Name  County            Township  Section     Site ID  STORETID  \
# 0    Beaver  Alpena  Ossineke and Green      NaN  Deep basin     40097
# 1    Beaver  Alpena  Ossineke and Green      NaN  Deep basin     40097
# 2    Beaver  Alpena  Ossineke and Green      NaN  Deep basin     40097
# 3    Beaver  Alpena  Ossineke and Green      NaN  Deep basin     40097
# 4    Beaver  Alpena  Ossineke and Green      NaN  Deep basin     40097
#
#     Latitude  Longitude  Watershed  Surface Area  ... Date Sampled  \
# 0  44.936115  -83.80004  4070006.0         621.0  ...   2006-07-21
# 1  44.936115  -83.80004  4070006.0         621.0  ...   2006-07-21
# 2  44.936115  -83.80004  4070006.0         621.0  ...   2006-07-21
# 3  44.936115  -83.80004  4070006.0         621.0  ...   2006-07-21
# 4  44.936115  -83.80004  4070006.0         621.0  ...   2006-07-21
#
#   Area Covered  # Transects # Sampling Sites Comments  Plant ID  \
# 0   Whole Lake           32              384      NaN        20
# ...
